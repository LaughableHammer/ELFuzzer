# %%
# Idk if this is helpful for others, I'm happy to add it to .gitignore if no one else will use it

# %%
import subprocess
import asyncio

# %%
normal = subprocess.run("./binaries/passcode", input=b"hi\n", capture_output=True)
print(normal)
print(normal.returncode)
fail = subprocess.run("./binaries/passcode", input=b"1234\n", capture_output=True)
print(fail)
print(fail.returncode)
# Out:
# CompletedProcess(args='./binaries/passcode', returncode=0, stdout=b'Hello, please enter code\n', stderr=b'')
# 0
